# %%
#                 NETFLIX PROJECT

#1. Remove the duplicates if there are any
#2.	Check whether there are any null values from the dataset
#3.	Print the director name of the show “House of cards”
#4.	In which year highest no. of TV shows and movies were released? Show with a bar chart
#5.	How many TV shows and movies are there in the dataset? Show with count plot
#6.	Show all the movies released in the year 2020
#7.	Show only the titles of all TV shows that were released in India
#8.	Show Top 10 directors who gave the highest no. of TV shows and movies to Netflix
#9.	Show all records “Category is Movies” and type is comedies or country is UK
#10.	In how many movies/shows, Tom Cruise acted?
#11.	What are the different ratings defined by Netflix?
#12.	Which country has maximum no. of TV shows?

# %%
import pandas as pd
ds=pd.read_csv('netflix.csv')
ds
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# if you want to rename the column name then use this!!

ds.rename(columns={'Cast': 'Actors'},inplace=True)

# to know the column name is changed or not ?
ds.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Actors', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# If you want to show the column name in the data set then use like this.

ds.to_csv('netflix_updated.csv',index=False)
ds
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                             Actors  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#1. Remove the duplicates if there are any

# to check if any duplicates in the data set

ds[ds.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                  Actors        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#used to remove the duplicate data

ds.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                             Actors  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#2.	Check whether there are any null values from the dataset

ds.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Actors           718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
ds=ds.dropna()
ds
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                  Actors  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
ds.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Actors          0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
#3.	Print the director name of the show “House of cards”

ds[ds.Title.str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                  Actors        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# it shows the director name of 'house of cards'

ds[ds.Title.str.contains('House of Cards')]['Director'].value_counts()
# Out:
# Director
# Robin Wright, David Fincher, Gerald McRaney, John David Coles, David Manson    1
# Name: count, dtype: int64

# %%
#4.	In which year highest no. of TV shows and movies were released? Show with a bar chart

ds.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Actors          object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
ds['Date']=pd.to_datetime(ds['Release_Date'],errors='coerce')
ds
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                             Actors  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# Now we created a new columns as date and year 

ds['Year']=ds['Date'].dt.year
ds
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                             Actors  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
ds['Year'].value_counts()
# Out:
# Year
# 2019.0    1337
# 2020.0    1230
# 2018.0    1114
# 2017.0     750
# 2016.0     207
# 2021.0      78
# 2015.0      50
# 2014.0      14
# 2011.0      13
# 2013.0       7
# 2012.0       3
# 2009.0       2
# 2010.0       1
# 2008.0       1
# Name: count, dtype: int64

# %%
#5.	How many TV shows and movies are there in the dataset? Show with count plot

ds.Category.value_counts()
# Out:
# Category
# Movie      4675
# TV Show     136
# Name: count, dtype: int64

# %%
ds['Year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(ds.Category)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
#6.	Show all the movies released in the year 2020

ds[(ds.Category=='Movies')&(ds.Year==2020)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Actors, Country, Release_Date, Rating, Duration, Type, Description, Date, Year]
# Index: []

# %%
#7.	Show only the titles of all TV shows that were released in India

ds[(ds.Category=='TV Show')&(ds.Country=='India')]
# Out:
#      Show_Id Category                                  Title  \
# 132     s133  TV Show                              7 (Seven)
# 2406   s2407  TV Show                                  GHOUL
# 3119   s3120  TV Show           Jamtara - Sabka Number Ayega
# 4724   s4725  TV Show                        Paava Kadhaigal
# 6037   s6037  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                Director  \
# 132                                         Nizar Shafi
# 2406                                     Patrick Graham
# 3119                                    Soumendra Padhi
# 4724  Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 6037                                      Dheeraj Berry
#
#                                                  Actors Country  \
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...   India
# 2406  Radhika Apte, Manav Kaul, Ratnabali Bhattachar...   India
# ...

# %%
# it shows only the title 

ds[(ds.Category=='TV Show')&(ds.Country=='India')]['Title']
# Out:
# 132                                 7 (Seven)
# 2406                                    GHOUL
# 3119             Jamtara - Sabka Number Ayega
# 4724                          Paava Kadhaigal
# 6037    Th Eena Meena Deeka Chase Comedy Show
# Name: Title, dtype: object

# %%
#8.	Show Top 10 directors who gave the highest no. of TV shows and movies to Netflix

ds['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter             18
# Marcus Raboy                       15
# Jay Karas                          14
# Cathy Garcia-Molina                13
# Jay Chapman                        12
#                                    ..
# Ilya Naishuller                     1
# Paresh Mokashi                      1
# Jon Hurwitz, Hayden Schlossberg     1
# Danny Leiner                        1
# Mozez Singh                         1
# Name: count, Length: 3614, dtype: int64

# %%
ds['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %%
#9.	Show all records “Category is Movies” and type is comedies or country is UK

ds[(ds.Category=='Movie')&(ds.Type=='Comedies')|(ds.Country=='United Kingdom')]
# Out:
#      Show_Id Category                       Title  \
# 33       s34    Movie                #realityhigh
# 72       s73    Movie                    17 Again
# 82       s83    Movie         2036 Origin Unknown
# 84       s85    Movie                   21 & Over
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7623   s7622    Movie                   Wild Oats
# 7634   s7633    Movie                Wine Country
# 7664   s7663    Movie                     Work It
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 33                          Fernando Lebrija
# 72                               Burr Steers
# 82                             Hasraf Dulull
# 84                    Jon Lucas, Scott Moore
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %%
ds[(ds.Category=='Movie')&(ds.Type=='Comedies')&(ds.Country=='United Kingdom')]
# Out:
#      Show_Id Category                                              Title  \
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2225   s2226    Movie                                  For Love or Money
# 4210   s4211    Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4213   s4214    Movie           Monty Python: Live at The Hollywood Bowl
# 4781   s4782    Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 4792   s4793    Movie                                     PATRICK (2019)
# 6109   s6109    Movie                            The Bad Education Movie
# 6947   s6946    Movie                                  The Trip to Spain
#
#                            Director  \
# 1368                  James Dearden
# 1650                    Tom Edmunds
# 2225                    Mark Murphy
# 4210                      Eric Idle
# 4213  Terry Hughes, Ian MacNaughton
# ...

# %%
#10.	In how many movies/shows, Tom Cruise acted?
ds[ds['Actors'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                  Actors        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       Date    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
# how many movies or shows 

ds[ds['Actors'].str.contains('Tom Cruise')]['Category'].count()
# Out:
# 2

# %%
#11.	What are the different ratings defined by Netflix?

ds['Rating'].nunique()
# Out:
# 14

# %%
ds['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
ds['Rating'].value_counts()
# Out:
# Rating
# TV-MA       1668
# TV-14       1133
# R            654
# TV-PG        413
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: count, dtype: int64

# %%
#12.	Which country has maximum no. of TV shows?

ds[ds.Category=='TV Show']['Country'].value_counts()
# Out:
# Country
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %%
# top 10 country 
ds[ds.Category=='TV Show']['Country'].value_counts().head(10)
# Out:
# Country
# United States     27
# United Kingdom    19
# Japan             10
# South Korea       10
# Spain              7
# Taiwan             6
# Turkey             5
# India              5
# Brazil             4
# Canada             3
# Name: count, dtype: int64

# %%
# top least country
ds[ds.Category=='TV Show']['Country'].value_counts().tail(10)
# Out:
# Country
# India, United States                                             1
# Australia                                                        1
# France, South Korea, Japan                                       1
# Colombia                                                         1
# Colombia, Mexico, United States                                  1
# United States, Ireland                                           1
# United States, Israel, Italy, South Africa                       1
# Italy, Canada, France                                            1
# United Kingdom, United States, Spain, Germany, Greece, Canada    1
# Italy, United States                                             1
# Name: count, dtype: int64
